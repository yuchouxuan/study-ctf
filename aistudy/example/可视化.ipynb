# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style="white", color_codes=True)
from sklearn.datasets import load_boston
iris_data =load_boston()
iris = pd.DataFrame(iris_data['data'], columns=iris_data['feature_names'])
#加载iris数据集
sns.pairplot(iris, hue='RAD', height=3, diag_kind='kde')
# Out:
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
labels = dict(zip([0,1,2], iris_data['target_names']))
#可以使用lambda关键字来创建一个小的匿名函数，他们在语法上限于单个表达式
#语法: lambda [arg1 [, arg2, ... argn]]: expression
iris['species'] = iris['species'].apply(lambda x: labels[x])
iris

# %%
labels
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
sns.distplot(iris[iris['species']=='setosa']['sepal length (cm)'])
# Out:
# c:\python3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='Density'>

# %%
# look at an individual feature in Seaborn through a boxplot盒图
sns.boxplot(x=1, y='TAX', data=iris)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-2931f9641add> in <module>
#       1 # look at an individual feature in Seaborn through a boxplot盒图
# ----> 2 sns.boxplot(x=1, y='TAX', data=iris)
#
# c:\python3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\python3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2228 ):
#    2229
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
# ...

# %%
# kdeplot looking at univariate relations
# creates and visualizes a kernel density estimate of the underlying feature核密度函数

sns.FacetGrid(iris, hue='species',height=6) \
   .map(sns.kdeplot, 'petal length (cm)') \
    .add_legend()

# %%
# A violin plot combines the benefits of the boxplot and kdeplot 
# Denser regions of the data are fatter, and sparser thiner in a violin plot

sns.violinplot(x='species', y='petal length (cm)', data=iris, size=6)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal length (cm)'>

# %%
# pairplot shows the bivariate relation between each pair of features
# From the pairplot, we'll see that the Iris-setosa species is separataed from the other two across all feature combinations
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde

sns.pairplot(iris, hue='species', height=3, diag_kind='kde')

# %%
# Andrews Curves involve using attributes of samples as coefficients for Fourier series and then plotting these

pd.plotting.andrews_curves(iris, 'species')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
## 数据准备
flights = sns.load_dataset("flights")
data = flights.pivot('year','month','passengers')
## S
sns.heatmap(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\python3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# c:\python3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# c:\python3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
g = sns.lmplot(data=iris, x='sepal width (cm)', y='sepal length (cm)',  hue= 'species')

# %%
fig=plt.gcf()
fig.set_size_inches(12, 8)
fig=sns.heatmap(iris.corr(), annot=True, cmap='GnBu', linewidths=1, linecolor='k', square=True, mask=False, vmin=-1, vmax=1, cbar_kws={"orientation": "vertical"}, cbar=True)

# %%
from sklearn.datasets import load_boston

boston = load_boston()
