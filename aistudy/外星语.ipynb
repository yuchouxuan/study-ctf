# %%
import cv2
import numpy as np 
import random
import torch 
from torch import nn
from torchvision import datasets, transforms,utils
import matplotlib.pyplot as plt
import tqdm.notebook as tdm
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

transform1 = transforms.Compose([transforms.ToTensor(), ]) # range [0, 255] -> [0.0,1.0]
transform2 = transforms.Compose([transforms.ToTensor(),  transforms.Normalize(mean = (0.5, 0.5, 0.5), std = (0.5, 0.5, 0.5))])

# %%
def pic_r(pic=np.ndarray(1)):
    x,y,r = random.randint(-12,12),random.randint(-12,12),random.randint(-50,50)
    
    M=cv2.getRotationMatrix2D((19,19),r,1)
    picrt=cv2.warpAffine(pic,M,(50,50))
    
    picrt=cv2.resize(picrt,(40+x,40+y))
    
    M=cv2.getRotationMatrix2D(((40+x)//2,(40+y)//2),r,0.8)
    picrt=cv2.warpAffine(picrt,M,(48,48))
    
    ret = transform1(picrt).numpy()
    return ret

imgorg={0:np.zeros((35, 35, 3))}

for i in range(26):
    C= i+1
    picpath='C:/ctf/pic/images/y_%02d.png'%(i+1)
    imgorg[C]=~cv2.imread(picpath,1)[3:40,3:40]

t_x=[]
t_y=[]
for i in tdm.trange(2000):
    for j in imgorg:
        t_x.append(pic_r(imgorg[j]))
        t_y.append(j)
p_x=[]
p_y=[]
for i in tdm.trange(100):
    for j in imgorg:
        p_x.append(pic_r(imgorg[j]))
        p_y.append(j)


len(t_x),len(p_y),len(p_x)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2000.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# (54000, 2700, 2700)

# %%
imgs=torch.tensor(t_x[:27*10])
grid = utils.make_grid(imgs,27,padding=0)
grid2 = grid.numpy().transpose(1,2,0) 
plt.figure(figsize=(24,24))
# # plt.figure(figsize=(20,20))
plt.imshow(grid2)
plt.show()

# %%
b_size=32

import torch.nn.functional as F
class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.conv1 = nn.Conv2d(3,b_size,kernel_size=3,stride=1,padding=1)
        self.pool = nn.MaxPool2d(2,2)
        
        self.conv2 = nn.Conv2d(b_size,64,kernel_size=3,stride=1,padding=1)
        self.fh0 = nn.Linear(9216,1024*3)#两个池化，
        self.fh2 = nn.Linear(1024*3,256)
        
        self.fo = nn.Linear(256,32)
        self.dp = nn.Dropout(p=0.3)
    def forward(self,x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))

        x = x.view(-1,9216)
        x = F.relu(self.fh0(x))
        x = self.dp(x)
        x = F.relu(self.fh2(x))  
        x = self.dp(x)
        x = self.fo(x)  
        return x
def draw_train_process(title,iters,costs,accs,label_cost,lable_acc):
    fig, axes = plt.subplots(1, 2, figsize=[16, 5])
    sns.lineplot(iters, costs,color='red',label=label_cost, ax = axes[0]) 
    sns.lineplot(iters, accs,color='green',label=lable_acc,ax=axes[1]) 
    plt.show()

# %%
net = CNN()

#net.load_state_dict(torch.load('c:/CTF/ctfshow_mr.ai'))

# %%
t_x = torch.tensor(np.array(t_x), dtype=torch.float)
t_y= torch.tensor(np.array(t_y), dtype=torch.long)

p_x = torch.tensor(np.array(p_x), dtype=torch.float)
# p_y= torch.tensor(np.array(p_y), dtype=torch.long)
len(t_x)
# q_x = torch.tensor(np.array(q_x), dtype=torch.float)
# q_y= torch.tensor(np.array(q_y), dtype=torch.long)
len(p_y)
# Out:
# 2700

# %%
import datetime as dt
import tqdm.notebook as tqnb
tstart=dt.datetime.now()
train_accs = []
train_loss = []



device = "cpu" 
device =torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
pxd=p_x.to(device)
net.to(device)

import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adagrad(net.parameters(), lr=0.001)
#optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
#optimizer = torch.optim.Adam(net.parameters(),lr=0.001)#Adam优化方法比较时髦

roundx=30
pbar = tqnb.tqdm(total=len(t_x)//b_size*roundx)
error=[]
zql=[]
cont=0
for epoch in range(roundx):
    for i  in  range(0,len(t_x),b_size):

        cont+=1
        inputs,labels = t_x[i:i+b_size].to(device), t_y[i:i+b_size].to(device)
        optimizer.zero_grad()         
        #前向+后向+优化     

        outputs = net.forward(inputs.to(device))
        loss = criterion(outputs,labels.to(device))
        loss.backward()
        optimizer.step()
        pbar.update(1)
        if cont%200 == 0 :
            yp=[]
            for pcnt in range(0,len(pxd),32): 
                y_pred = net(pxd[pcnt:pcnt+32])
                y_pred = torch.argmax(y_pred, dim=1).cpu()
                yp.extend(y_pred.numpy())
            zql.append(float(accuracy_score(p_y,yp )))
            error.append(loss.item())
pbar.close()

dt.datetime.now()-tstart

import seaborn as sns

sns.lineplot(data=error,color='red',label='loss')
sns.lineplot(data=zql,color='green',label='acc')
print(classification_report(p_y, yp))

torch.cuda.empty_cache()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=50610.0), HTML(value='')))
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       0.95      0.98      0.97       100
#            2       0.98      1.00      0.99       100
#            3       0.94      0.95      0.95       100
#            4       0.99      0.98      0.98       100
#            5       0.99      0.99      0.99       100
#            6       0.96      0.94      0.95       100
#            7       0.99      0.98      0.98       100
#            8       0.96      0.98      0.97       100
#            9       0.95      0.94      0.94       100
#           10       1.00      0.98      0.99       100
#           11       0.97      0.92      0.94       100
#           12       0.94      0.98      0.96       100
#           13       0.99      0.99      0.99       100
#           14       0.80      0.79      0.79       100
#           15       0.83      0.81      0.82       100
#           16       0.92      0.97      0.94       100
#           17       0.96      0.97      0.97       100
#           18       1.00      0.97      0.98       100
#           19       0.93      0.93      0.93       100
#           20       0.96      0.97      0.97       100
#           21       0.92      0.95      0.94       100
#           22       0.96      0.93      0.94       100
#           23       0.97      1.00      0.99       100
#           24       0.97      0.96      0.96       100
#           25       0.97      0.92      0.94       100
#           26       0.98      0.99      0.99       100
#
#     accuracy                           0.95      2700
#    macro avg       0.95      0.95      0.95      2700
# weighted avg       0.95      0.95      0.95      2700

# %%
#torch.save(net.state_dict(),'c:/CTF/ctfshow_mr.ai')

# %%
#torch.save(net.state_dict(),'c:/CTF/ctfshow_mr.ai')
m=u'''听说白雪公主在逃跑
小红帽在担心大灰狼
听说疯帽喜欢爱丽丝
丑小鸭会变成白天鹅
听说彼得潘总长不大
杰克他有竖琴和魔法
听说森林里有糖果屋
灰姑娘丢了心爱的玻璃鞋
只有睿智的河水知道
白雪是因为贪玩跑出了城堡
小红帽有件抑制自己
变成狼的大红袍
总有一条蜿蜒在童话镇里七彩的河
沾染魔法的乖张气息
却又在爱里曲折
川流不息扬起水花
又卷入一帘时光入水
让所有很久很久以前
都走到幸福结局的时刻
听说睡美人被埋藏
小人鱼在眺望金殿堂
听说阿波罗变成金乌
草原有奔跑的剑齿虎
听说匹诺曹总说着谎
侏儒怪拥有宝石满箱
听说悬崖有棵长生树
红鞋子不知疲倦地在跳舞
只有睿智的河水知道
睡美人逃避了生活的煎熬
小人鱼把阳光抹成眼影
投进泡沫的怀抱
总有一条蜿蜒在童话镇里七彩的河
沾染魔法的乖张气息
却又在爱里曲折
川流不息扬起水花
又卷入一帘时光入水
让所有很久很久以前
都走到幸福结局的时刻
总有一条蜿蜒在童话镇里梦幻的河
分隔了理想分隔现实
又在前方的山口汇合
川流不息扬起水花
又卷入一帘时光入水
让所有很久很久以前
都走到幸福结局的时刻 又陌生
弗莱格是：
避席畏闻文字狱_著书只为稻粱谋
记得自己加皮哦'''.encode()
c=[]
for i in m:
    a0=i//26
    a1=i%26
    c.extend([a0+1,a1+1,0])

for p in range(3):
    picout=[]
    for i in c:
        picout.append(pic_r(imgorg[i]))
    imgs=torch.tensor(picout)
    utils.save_image(imgs,'c:/CTF/flag%d.png'%(p+1),27*2,padding=0)

cc=c
len(c),cc,m
# Out:
# (4224,
#  [9,
#   22,
#   0,
#   6,
#   15,
#   0,
#   7,
#   17,
#   0,
#   9,
#   25,
#   0,
#   7,
#   20,
#   0,
#   7,
#   25,
#   0,
#   9,
#   24,
#   0,
#   6,
#   24,
#   0,
#   8,
#   8,
#   0,
#   9,
#   26,
#   0,
#   6,
#   26,
#   0,
#   7,
#   15,
#   0,
#   9,
#   22,
#   0,
#   6,
#   4,
#   0,
#   7,
#   17,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   8,
#   6,
#   0,
#   9,
#   22,
#   0,
#   7,
#   1,
#   0,
#   7,
#   13,
#   0,
#   9,
#   26,
#   0,
#   5,
#   25,
#   0,
#   6,
#   2,
#   0,
#   9,
#   25,
#   0,
#   8,
#   2,
#   0,
#   6,
#   16,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   7,
#   21,
#   0,
#   6,
#   14,
#   0,
#   9,
#   24,
#   0,
#   8,
#   5,
#   0,
#   7,
#   7,
#   0,
#   9,
#   22,
#   0,
#   8,
#   3,
#   0,
#   8,
#   8,
#   0,
#   9,
#   22,
#   0,
#   7,
#   1,
#   0,
#   7,
#   13,
#   0,
#   9,
#   23,
#   0,
#   6,
#   10,
#   0,
#   6,
#   4,
#   0,
#   9,
#   22,
#   0,
#   8,
#   10,
#   0,
#   6,
#   2,
#   0,
#   9,
#   22,
#   0,
#   7,
#   9,
#   0,
#   7,
#   12,
#   0,
#   9,
#   24,
#   0,
#   5,
#   26,
#   0,
#   7,
#   21,
#   0,
#   9,
#   24,
#   0,
#   6,
#   10,
#   0,
#   8,
#   7,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   6,
#   15,
#   0,
#   7,
#   17,
#   0,
#   9,
#   25,
#   0,
#   7,
#   20,
#   0,
#   7,
#   25,
#   0,
#   9,
#   24,
#   0,
#   6,
#   21,
#   0,
#   7,
#   20,
#   0,
#   9,
#   22,
#   0,
#   8,
#   3,
#   0,
#   8,
#   8,
#   0,
#   9,
#   22,
#   0,
#   6,
#   21,
#   0,
#   7,
#   1,
#   0,
#   9,
#   23,
#   0,
#   7,
#   17,
#   0,
#   7,
#   7,
#   0,
#   9,
#   24,
#   0,
#   6,
#   7,
#   0,
#   7,
#   22,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   8,
#   8,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   7,
#   2,
#   0,
#   1,
#   11,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   6,
#   16,
#   0,
#   9,
#   22,
#   0,
#   7,
#   21,
#   0,
#   6,
#   14,
#   0,
#   9,
#   26,
#   0,
#   8,
#   3,
#   0,
#   7,
#   18,
#   0,
#   9,
#   21,
#   0,
#   8,
#   7,
#   0,
#   6,
#   25,
#   0,
#   9,
#   22,
#   0,
#   6,
#   14,
#   0,
#   6,
#   23,
#   0,
#   9,
#   23,
#   0,
#   6,
#   7,
#   0,
#   6,
#   15,
#   0,
#   9,
#   24,
#   0,
#   6,
#   24,
#   0,
#   8,
#   8,
#   0,
#   9,
#   22,
#   0,
#   7,
#   9,
#   0,
#   7,
#   14,
#   0,
#   9,
#   26,
#   0,
#   8,
#   4,
#   0,
#   6,
#   4,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   6,
#   15,
#   0,
#   7,
#   17,
#   0,
#   9,
#   25,
#   0,
#   7,
#   20,
#   0,
#   7,
#   25,
#   0,
#   9,
#   22,
#   0,
#   8,
#   8,
#   0,
#   8,
#   7,
#   0,
#   9,
#   22,
#   0,
#   8,
#   9,
#   0,
#   6,
#   22,
#   0,
#   9,
#   23,
#   0,
#   8,
#   8,
#   0,
#   6,
#   23,
#   0,
#   9,
#   23,
#   0,
#   5,
#   25,
#   0,
#   8,
#   6,
#   0,
#   9,
#   26,
#   0,
#   6,
#   20,
#   0,
#   8,
#   10,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   6,
#   12,
#   0,
#   9,
#   22,
#   0,
#   7,
#   9,
#   0,
#   7,
#   12,
#   0,
#   1,
#   11,
#   0,
#   9,
#   23,
#   0,
#   7,
#   2,
#   0,
#   7,
#   21,
#   0,
#   9,
#   22,
#   0,
#   6,
#   4,
#   0,
#   6,
#   10,
#   0,
#   9,
#   21,
#   0,
#   8,
#   6,
#   0,
#   6,
#   21,
#   0,
#   9,
#   23,
#   0,
#   7,
#   1,
#   0,
#   6,
#   8,
#   0,
#   9,
#   24,
#   0,
#   7,
#   16,
#   0,
#   6,
#   21,
#   0,
#   9,
#   24,
#   0,
#   6,
#   15,
#   0,
#   7,
#   25,
#   0,
#   9,
#   22,
#   0,
#   6,
#   17,
#   0,
#   6,
#   11,
#   0,
#   9,
#   26,
#   0,
#   7,
#   18,
#   0,
#   6,
#   19,
#   0,
#   9,
#   23,
#   0,
#   7,
#   24,
#   0,
#   6,
#   20,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   6,
#   15,
#   0,
#   7,
#   17,
#   0,
#   9,
#   25,
#   0,
#   7,
#   20,
#   0,
#   7,
#   25,
#   0,
#   9,
#   23,
#   0,
#   7,
#   8,
#   0,
#   7,
#   19,
#   0,
#   9,
#   23,
#   0,
#   7,
#   3,
#   0,
#   6,
#   22,
#   0,
#   9,
#   26,
#   0,
#   6,
#   6,
#   0,
#   6,
#   11,
#   0,
#   9,
#   23,
#   0,
#   7,
#   1,
#   0,
#   6,
#   8,
#   0,
#   9,
#   24,
#   0,
#   7,
#   24,
#   0,
#   6,
#   21,
#   0,
#   9,
#   23,
#   0,
#   7,
#   3,
#   0,
#   7,
#   1,
#   0,
#   9,
#   22,
#   0,
#   7,
#   22,
#   0,
#   6,
#   10,
#   0,
#   1,
#   11,
#   0,
#   9,
#   24,
#   0,
#   5,
#   26,
#   0,
#   7,
#   21,
#   0,
#   9,
#   22,
#   0,
#   7,
#   12,
#   0,
#   6,
#   16,
#   0,
#   9,
#   22,
#   0,
#   7,
#   13,
#   0,
#   6,
#   23,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   7,
#   7,
#   0,
#   9,
#   21,
#   0,
#   8,
#   5,
#   0,
#   6,
#   5,
#   0,
#   9,
#   22,
#   0,
#   8,
#   10,
#   0,
#   6,
#   2,
#   0,
#   9,
#   24,
#   0,
#   6,
#   7,
#   0,
#   7,
#   22,
#   0,
#   9,
#   24,
#   0,
#   6,
#   25,
#   0,
#   6,
#   3,
#   0,
#   9,
#   24,
#   0,
#   6,
#   13,
#   0,
#   8,
#   6,
#   0,
#   9,
#   24,
#   0,
#   6,
#   17,
#   0,
#   6,
#   2,
#   0,
#   9,
#   26,
#   0,
#   7,
#   3,
#   0,
#   6,
#   10,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   6,
#   14,
#   0,
#   7,
#   15,
#   0,
#   9,
#   23,
#   0,
#   7,
#   1,
#   0,
#   6,
#   8,
#   0,
#   9,
#   24,
#   0,
#   7,
#   2,
#   0,
#   8,
#   10,
#   0,
#   9,
#   23,
#   0,
#   6,
#   24,
#   0,
#   8,
#   5,
#   0,
#   9,
#   24,
#   0,
#   6,
#   25,
#   0,
#   6,
#   3,
#   0,
#   9,
#   23,
#   0,
#   7,
#   23,
#   0,
#   7,
#   24,
#   0,
#   9,
#   23,
#   0,
#   7,
#   21,
#   0,
#   7,
#   25,
#   0,
#   9,
#   24,
#   0,
#   7,
#   4,
#   0,
#   7,
#   10,
#   0,
#   9,
#   26,
#   0,
#   5,
#   26,
#   0,
#   6,
#   18,
#   0,
#   1,
#   11,
#   0,
#   9,
#   24,
#   0,
#   6,
#   24,
#   0,
#   8,
#   8,
#   0,
#   9,
#   26,
#   0,
#   6,
#   26,
#   0,
#   7,
#   15,
#   0,
#   9,
#   23,
#   0,
#   6,
#   23,
#   0,
#   7,
#   20,
#   0,
#   9,
#   22,
#   0,
#   6,
#   26,
#   0,
#   7,
#   5,
#   0,
#   9,
#   21,
#   0,
#   8,
#   3,
#   0,
#   8,
#   5,
#   0,
#   9,
#   25,
#   0,
#   7,
#   25,
#   0,
#   7,
#   15,
#   0,
#   9,
#   24,
#   0,
#   6,
#   13,
#   0,
#   7,
#   14,
#   0,
#   9,
#   25,
#   0,
#   8,
#   2,
#   0,
#   6,
#   16,
#   0,
#   9,
#   22,
#   0,
#   6,
#   6,
#   0,
#   8,
#   5,
#   0,
#   9,
#   21,
#   0,
#   8,
#   5,
#   0,
#   6,
#   5,
#   0,
#   9,
#   22,
#   0,
#   7,
#   4,
#   0,
#   6,
#   13,
#   0,
#   9,
#   22,
#   0,
#   7,
#   5,
#   0,
#   7,
#   6,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   7,
#   21,
#   0,
#   6,
#   14,
#   0,
#   9,
#   24,
#   0,
#   8,
#   5,
#   0,
#   7,
#   7,
#   0,
#   9,
#   22,
#   0,
#   8,
#   3,
#   0,
#   8,
#   8,
#   0,
#   9,
#   23,
#   0,
#   7,
#   1,
#   0,
#   6,
#   8,
#   0,
#   9,
#   21,
#   0,
#   8,
#   6,
#   0,
#   8,
#   1,
#   0,
#   9,
#   23,
#   0,
#   6,
#   9,
#   0,
#   6,
#   16,
#   0,
#   9,
#   22,
#   0,
#   6,
#   7,
#   0,
#   8,
#   1,
#   0,
#   9,
#   25,
#   0,
#   6,
#   6,
#   0,
#   7,
#   15,
#   0,
#   9,
#   22,
#   0,
#   8,
#   2,
#   0,
#   7,
#   22,
#   0,
#   1,
#   11,
#   0,
#   9,
#   22,
#   0,
#   6,
#   14,
#   0,
#   6,
#   23,
#   0,
#   9,
#   23,
#   0,
#   6,
#   7,
#   0,
#   6,
#   15,
#   0,
#   9,
#   24,
#   0,
#   6,
#   10,
#   0,
#   8,
#   7,
#   0,
#   9,
#   24,
#   0,
#   6,
#   ...],
#  b'\xe5\x90\xac\xe8\xaf\xb4\xe7\x99\xbd\xe9\x9b\xaa\xe5\x85\xac\xe4\xb8\xbb\xe5\x9c\xa8\xe9\x80\x83\xe8\xb7\x91\n\xe5\xb0\x8f\xe7\xba\xa2\xe5\xb8\xbd\xe5\x9c\xa8\xe6\x8b\x85\xe5\xbf\x83\xe5\xa4\xa7\xe7\x81\xb0\xe7\x8b\xbc\n\xe5\x90\xac\xe8\xaf\xb4\xe7\x96\xaf\xe5\xb8\xbd\xe5\x96\x9c\xe6\xac\xa2\xe7\x88\xb1\xe4\xb8\xbd\xe4\xb8\x9d\n\xe4\xb8\x91\xe5\xb0\x8f\xe9\xb8\xad\xe4\xbc\x9a\xe5\x8f\x98\xe6\x88\x90\xe7\x99\xbd\xe5\xa4\xa9\xe9\xb9\x85\n\xe5\x90\xac\xe8\xaf\xb4\xe5\xbd\xbc\xe5\xbe\x97\xe6\xbd\x98\xe6\x80\xbb\xe9\x95\xbf\xe4\xb8\x8d\xe5\xa4\xa7\n\xe6\x9d\xb0\xe5\x85\x8b\xe4\xbb\x96\xe6\x9c\x89\xe7\xab\x96\xe7\x90\xb4\xe5\x92\x8c\xe9\xad\x94\xe6\xb3\x95\n\xe5\x90\xac\xe8\xaf\xb4\xe6\xa3\xae\xe6\x9e\x97\xe9\x87\x8c\xe6\x9c\x89\xe7\xb3\x96\xe6\x9e\x9c\xe5\xb1\x8b\n\xe7\x81\xb0\xe5\xa7\x91\xe5\xa8\x98\xe4\xb8\xa2\xe4\xba\x86\xe5\xbf\x83\xe7\x88\xb1\xe7\x9a\x84\xe7\x8e\xbb\xe7\x92\x83\xe9\x9e\x8b\n\xe5\x8f\xaa\xe6\x9c\x89\xe7\x9d\xbf\xe6\x99\xba\xe7\x9a\x84\xe6\xb2\xb3\xe6\xb0\xb4\xe7\x9f\xa5\xe9\x81\x93\n\xe7\x99\xbd\xe9\x9b\xaa\xe6\x98\xaf\xe5\x9b\xa0\xe4\xb8\xba\xe8\xb4\xaa\xe7\x8e\xa9\xe8\xb7\x91\xe5\x87\xba\xe4\xba\x86\xe5\x9f\x8e\xe5\xa0\xa1\n\xe5\xb0\x8f\xe7\xba\xa2\xe5\xb8\xbd\xe6\x9c\x89\xe4\xbb\xb6\xe6\x8a\x91\xe5\x88\xb6\xe8\x87\xaa\xe5\xb7\xb1\n\xe5\x8f\x98\xe6\x88\x90\xe7\x8b\xbc\xe7\x9a\x84\xe5\xa4\xa7\xe7\xba\xa2\xe8\xa2\x8d\n\xe6\x80\xbb\xe6\x9c\x89\xe4\xb8\x80\xe6\x9d\xa1\xe8\x9c\xbf\xe8\x9c\x92\xe5\x9c\xa8\xe7\xab\xa5\xe8\xaf\x9d\xe9\x95\x87\xe9\x87\x8c\xe4\xb8\x83\xe5\xbd\xa9\xe7\x9a\x84\xe6\xb2\xb3\n\xe6\xb2\xbe\xe6\x9f\x93\xe9\xad\x94\xe6\xb3\x95\xe7\x9a\x84\xe4\xb9\x96\xe5\xbc\xa0\xe6\xb0\x94\xe6\x81\xaf\n\xe5\x8d\xb4\xe5\x8f\x88\xe5\x9c\xa8\xe7\x88\xb1\xe9\x87\x8c\xe6\x9b\xb2\xe6\x8a\x98\n\xe5\xb7\x9d\xe6\xb5\x81\xe4\xb8\x8d\xe6\x81\xaf\xe6\x89\xac\xe8\xb5\xb7\xe6\xb0\xb4\xe8\x8a\xb1\n\xe5\x8f\x88\xe5\x8d\xb7\xe5\x85\xa5\xe4\xb8\x80\xe5\xb8\x98\xe6\x97\xb6\xe5\x85\x89\xe5\x85\xa5\xe6\xb0\xb4\n\xe8\xae\xa9\xe6\x89\x80\xe6\x9c\x89\xe5\xbe\x88\xe4\xb9\x85\xe5\xbe\x88\xe4\xb9\x85\xe4\xbb\xa5\xe5\x89\x8d\n\xe9\x83\xbd\xe8\xb5\xb0\xe5\x88\xb0\xe5\xb9\xb8\xe7\xa6\x8f\xe7\xbb\x93\xe5\xb1\x80\xe7\x9a\x84\xe6\x97\xb6\xe5\x88\xbb\n\xe5\x90\xac\xe8\xaf\xb4\xe7\x9d\xa1\xe7\xbe\x8e\xe4\xba\xba\xe8\xa2\xab\xe5\x9f\x8b\xe8\x97\x8f\n\xe5\xb0\x8f\xe4\xba\xba\xe9\xb1\xbc\xe5\x9c\xa8\xe7\x9c\xba\xe6\x9c\x9b\xe9\x87\x91\xe6\xae\xbf\xe5\xa0\x82\n\xe5\x90\xac\xe8\xaf\xb4\xe9\x98\xbf\xe6\xb3\xa2\xe7\xbd\x97\xe5\x8f\x98\xe6\x88\x90\xe9\x87\x91\xe4\xb9\x8c\n\xe8\x8d\x89\xe5\x8e\x9f\xe6\x9c\x89\xe5\xa5\x94\xe8\xb7\x91\xe7\x9a\x84\xe5\x89\x91\xe9\xbd\xbf\xe8\x99\x8e\n\xe5\x90\xac\xe8\xaf\xb4\xe5\x8c\xb9\xe8\xaf\xba\xe6\x9b\xb9\xe6\x80\xbb\xe8\xaf\xb4\xe7\x9d\x80\xe8\xb0\x8e\n\xe4\xbe\x8f\xe5\x84\x92\xe6\x80\xaa\xe6\x8b\xa5\xe6\x9c\x89\xe5\xae\x9d\xe7\x9f\xb3\xe6\xbb\xa1\xe7\xae\xb1\n\xe5\x90\xac\xe8\xaf\xb4\xe6\x82\xac\xe5\xb4\x96\xe6\x9c\x89\xe6\xa3\xb5\xe9\x95\xbf\xe7\x94\x9f\xe6\xa0\x91\n\xe7\xba\xa2\xe9\x9e\x8b\xe5\xad\x90\xe4\xb8\x8d\xe7\x9f\xa5\xe7\x96\xb2\xe5\x80\xa6\xe5\x9c\xb0\xe5\x9c\xa8\xe8\xb7\xb3\xe8\x88\x9e\n\xe5\x8f\xaa\xe6\x9c\x89\xe7\x9d\xbf\xe6\x99\xba\xe7\x9a\x84\xe6\xb2\xb3\xe6\xb0\xb4\xe7\x9f\xa5\xe9\x81\x93\n\xe7\x9d\xa1\xe7\xbe\x8e\xe4\xba\xba\xe9\x80\x83\xe9\x81\xbf\xe4\xba\x86\xe7\x94\x9f\xe6\xb4\xbb\xe7\x9a\x84\xe7\x85\x8e\xe7\x86\xac\n\xe5\xb0\x8f\xe4\xba\xba\xe9\xb1\xbc\xe6\x8a\x8a\xe9\x98\xb3\xe5\x85\x89\xe6\x8a\xb9\xe6\x88\x90\xe7\x9c\xbc\xe5\xbd\xb1\n\xe6\x8a\x95\xe8\xbf\x9b\xe6\xb3\xa1\xe6\xb2\xab\xe7\x9a\x84\xe6\x80\x80\xe6\x8a\xb1\n\xe6\x80\xbb\xe6\x9c\x89\xe4\xb8\x80\xe6\x9d\xa1\xe8\x9c\xbf\xe8\x9c\x92\xe5\x9c\xa8\xe7\xab\xa5\xe8\xaf\x9d\xe9\x95\x87\xe9\x87\x8c\xe4\xb8\x83\xe5\xbd\xa9\xe7\x9a\x84\xe6\xb2\xb3\n\xe6\xb2\xbe\xe6\x9f\x93\xe9\xad\x94\xe6\xb3\x95\xe7\x9a\x84\xe4\xb9\x96\xe5\xbc\xa0\xe6\xb0\x94\xe6\x81\xaf\n\xe5\x8d\xb4\xe5\x8f\x88\xe5\x9c\xa8\xe7\x88\xb1\xe9\x87\x8c\xe6\x9b\xb2\xe6\x8a\x98\n\xe5\xb7\x9d\xe6\xb5\x81\xe4\xb8\x8d\xe6\x81\xaf\xe6\x89\xac\xe8\xb5\xb7\xe6\xb0\xb4\xe8\x8a\xb1\n\xe ...

# %%
f1=cv2.imread('c:/CTF/flag1.png',1)
f2=cv2.imread('c:/CTF/flag2.png',1)
f3=cv2.imread('c:/CTF/flag3.png',1)
f1.shape,f3.shape[0]/48,f3.shape[1]/48
row=81
col=54
net.cpu()



def getchars_from_picAfox(fn=''):
    p1=[]
    f1=cv2.imread(fn,1)
    for r in range(0,f1.shape[0],48):
        for c in range(0,f1.shape[1],48):
            appx = f1[r:r+48,c:c+48]
            p1.append(transform1(appx).numpy())
    p1=torch.tensor(np.array(p1[:4326]), dtype=torch.float)
    y1=torch.tensor(np.array(cc), dtype=torch.float)
    y_pred = net(p1)
    y_pred = torch.argmax(y_pred, dim=1)
    return y_pred.numpy()


c1=(getchars_from_picAfox('c:/CTF/flag1.png'))
c2=(getchars_from_picAfox('c:/CTF/flag2.png'))
c3=(getchars_from_picAfox('c:/CTF/flag3.png'))
c1,c2,c3
# Out:
# (array([ 9, 22,  0, ...,  0,  0,  0], dtype=int64),
#  array([ 9, 22,  0, ...,  0,  0,  0], dtype=int64),
#  array([ 9, 22,  0, ...,  0,  0,  0], dtype=int64))

# %%
import pandas as pd
cset=np.array([c1,c2,c3]).T
c=[]
for i in cset:
    c.append(int(np.median(i)))
strx=u''
fwb=[]
for i in range(0,len(c),3):
    w = (c[i]-1)*26+c[i+1]-1
#     print(c[i],c[i+1],hex(w))
    fwb.append(w&0xff)
    strx+=chr(w&0xff)
open('c:/CTF/fw.txt','wb').write(bytes(fwb))
print(fwb)
# Out:
# [229, 143, 172, 232, 175, 180, 231, 153, 189, 233, 155, 170, 229, 133, 172, 228, 184, 187, 229, 156, 168, 233, 128, 131, 232, 183, 145, 6, 229, 176, 143, 231, 186, 162, 229, 184, 189, 229, 156, 168, 230, 139, 133, 229, 191, 131, 229, 164, 167, 231, 129, 176, 231, 139, 188, 10, 229, 144, 172, 232, 175, 180, 231, 150, 175, 229, 184, 189, 73, 150, 156, 230, 172, 162, 231, 136, 177, 228, 184, 189, 228, 184, 157, 10, 228, 184, 145, 229, 176, 143, 233, 184, 173, 228, 188, 154, 229, 143, 152, 230, 136, 144, 231, 153, 189, 229, 164, 169, 233, 185, 133, 10, 229, 144, 172, 232, 175, 180, 229, 189, 188, 229, 190, 151, 230, 189, 152, 230, 128, 187, 233, 149, 191, 228, 184, 141, 229, 164, 167, 10, 230, 157, 176, 229, 133, 139, 228, 187, 150, 230, 156, 137, 231, 171, 150, 231, 144, 180, 229, 146, 140, 233, 173, 148, 230, 179, 149, 10, 229, 144, 172, 232, 175, 180, 230, 171, 174, 230, 158, 151, 233, 135, 140, 230, 156, 137, 231, 179, 150, 230, 158, 156, 229, 177, 139, 10, 231, 129, 176, 229, 167, 145, 229, 168, 152, 228, 184, 162, 228, 186, 134, 229, 191, 131, 231, 136, 177, 231, 154, 132, 231, 142, 187, 231, 146, 131, 233, 158, 139, 10, 229, 143, 170, 230, 156, 137, 231, 157, 191, 230, 153, 186, 231, 154, 132, 230, 178, 179, 230, 176, 180, 231, 159, 165, 233, 129, 147, 10, 231, 153, 189, 233, 155, 170, 230, 152, 175, 229, 155, 160, 228, 184, 186, 232, 180, 170, 231, 142, 169, 232, 183, 145, 229, 135, 186, 228, 186, 134, 229, 159, 142, 229, 160, 161, 10, 229, 176, 143, 231, 186, 162, 229, 184, 189, 230, 156, 137, 228, 187, 182, 230, 138, 145, 229, 136, 182, 232, 135, 170, 229, 183, 177, 10, 229, 143, 152, 230, 136, 144, 231, 139, 188, 231, 154, 132, 229, 164, 167, 231, 186, 162, 232, 162, 141, 10, 230, 128, 187, 230, 156, 137, 228, 184, 128, 230, 157, 161, 232, 156, 191, 232, 156, 146, 229, 156, 168, 231, 171, 165, 232, 175, 157, 233, 149, 135, 233, 135, 140, 228, 184, 131, 229, 189, 169, 231, 154, 132, 230, 178, 179, 10, 230, 178, 190, 230, 159, 147, 233, 173, 148, 230, 179, 149, 231, 154, 132, 228, 185, 150, 229, 188, 160, 230, 176, 148, 230, 129, 175, 10, 229, 141, 180, 229, 143, 136, 229, 156, 168, 231, 136, 177, 233, 135, 140, 230, 155, 178, 230, 138, 152, 10, 229, 183, 157, 230, 181, 129, 228, 184, 141, 230, 129, 175, 230, 137, 172, 232, 181, 183, 230, 176, 180, 232, 138, 177, 10, 229, 143, 136, 229, 141, 183, 229, 133, 165, 228, 184, 128, 229, 184, 152, 230, 151, 182, 229, 133, 137, 229, 133, 165, 230, 176, 180, 10, 232, 174, 169, 230, 137, 128, 230, 156, 137, 229, 190, 136, 228, 185, 133, 229, 190, 136, 228, 185, 133, 228, 187, 165, 229, 137, 141, 10, 233, 131, 189, 232, 181, 176, 229, 136, 176, 229, 185, 184, 231, 166, 143, 231, 187, 147, 229, 177, 128, 231, 154, 132, 230, 151, 182, 229, 136, 187, 10, 229, 144, 172, 232, 175, 180, 231, 157, 161, 231, 190, 142, 228, 186, 186, 232, 162, 171, 229, 159, 139, 232, 151, 143, 10, 229, 176, 143, 228, 186, 186, 233, 177, 188, 229, 156, 168, 231, 156, 186, 230, 156, 155, 233, 135, 145, 230, 174, 191, 229, 160, 130, 10, 229, 144, 172, 232, 175, 180, 233, 152, 191, 230, 179, 162, 231, 189, 151, 229, 143, 152, 230, 136, 144, 233, 135, 145, 228, 185, 140, 10, 232, 141, 137, 229, 142, 159, 230, 156, 137, 229, 165, 148, 232, 183, 145, 231, 154, 132, 229, 137, 145, 233, 189, 191, 232, 153, 142, 10, 229, 144, 172, 232, 175, 180, 229, 140, 185, 232, 175, 186, 230, 155, 185, 230, 128, 187, 232, 175, 180, 231, 157, 128, 232, 176, 142, 10, 228, 190, 143, 229, 132, 146, 230, 128, 170, 230, 139, 165, 230, 156, 137, 229, 174, 157, 231, 159, 179, 230, 187, 161, 231, 174, 177, 10, 229, 144, 172, 232, 175, 180, 230, 130, 172, 229, 180, 150, 230, 156, 137, 152, 163, 181, 233, 149, 191, 231, 148, 159, 230, 160, 145, 10, 231, 186, 162, 233, 158, 139, 229, 173, 144, 228, 184, 141, 231, 159, 165, 231, 150, 178, 229, 128, 166, 229, 156, 176, 229, 156, 168, 232, 183, 179, 232, 136, 158, 10, 229, 143, 170, 230, 156, 137, 231, 157, 191, 230, 153, 186, 231, 154, 132, 230, 178, 179, 230, 176, 180, 231, 159, 165, 233, 129 ...
